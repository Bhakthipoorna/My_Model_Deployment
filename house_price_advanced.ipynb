# %%
#Importing required packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Reading dataset
data=pd.read_csv('data.csv')
data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
data.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
#sns.pairplot(data)

# %%
#Dropping columns
data.drop('Id',axis=1,inplace=True)
data.drop('Alley',axis=1,inplace=True)
data.drop('PoolQC',axis=1,inplace=True)
data.drop('Fence',axis=1,inplace=True)   
data.drop('MiscFeature',axis=1,inplace=True)
data.drop('FireplaceQu',axis=1,inplace=True)

# %%
#Filling null values
data['LotFrontage'].fillna(data['LotFrontage'].mean(),inplace=True)
data['MasVnrType'].fillna('None',inplace=True)
data['MasVnrArea'].fillna(data['MasVnrArea'].mean(),inplace=True)
data['BsmtQual'].fillna('unknown',inplace=True) 
data['BsmtCond'].fillna('TA',inplace=True)
data['BsmtExposure'].fillna('No',inplace=True)
data['BsmtFinType1'].fillna('unknown',inplace=True)
data['BsmtFinType2'].fillna('Unf',inplace=True)
data['Electrical'].fillna('SBrkr',inplace=True)
data['GarageType'].fillna('unknown',inplace=True) 
data['GarageYrBlt'].fillna(data['GarageYrBlt'].mean(),inplace=True)
data['GarageFinish'].fillna('unknown',inplace=True)
data['GarageQual'].fillna('TA',inplace=True)
data['GarageCond'].fillna('TA',inplace=True)

# %%
sns.heatmap(data.isnull())

# %%
data_object=data.loc[:,data.dtypes==np.object]
print(data_object.columns)


from sklearn.preprocessing import LabelEncoder
label=LabelEncoder()
df=data.copy()
df[['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities',
       'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
       'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
       'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
       'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
       'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
       'Functional', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond',
       'PavedDrive', 'SaleType', 'SaleCondition']]=df[['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities',
       'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
       'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
       'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
       'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
       'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
       'Functional', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond',
       'PavedDrive', 'SaleType', 'SaleCondition']].apply(label.fit_transform)

df
# Out:
# Index(['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond',
#        'PavedDrive', 'SaleType', 'SaleCondition'],
#       dtype='object')
#       MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  \
# 0             60         3         65.0     8450       1         3
# 1             20         3         80.0     9600       1         3
# 2             60         3         68.0    11250       1         0
# 3             70         3         60.0     9550       1         0
# ...

# %%
#Detecting and removing outliers

from  scipy import stats
z=np.abs(stats.zscore(df))
z

threshold=3
print(np.where(z>3))

dff=df[(z<3).all(axis=1)]
# Out:
# (array([   1,    3,    3, ..., 1458, 1458, 1459], dtype=int64), array([46, 65, 73, ..., 34, 40, 63], dtype=int64))

# %%
dff
# Out:
#       MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  \
# 0             60         3    65.000000     8450       1         3
# 2             60         3    68.000000    11250       1         0
# 4             60         3    84.000000    14260       1         0
# 6             20         3    75.000000    10084       1         3
# 10            20         3    70.000000    11200       1         3
# ...          ...       ...          ...      ...     ...       ...
# 1446          20         3    70.049958    26142       1         0
# 1447          60         3    80.000000    10000       1         3
# 1451          20         3    78.000000     9262       1         3
# 1452         180         4    35.000000     3675       1         3
# 1455          60         3    62.000000     7917       1         3
#
#       LandContour  Utilities  LotConfig  LandSlope  ...  EnclosedPorch  \
# 0               3          0          4          0  ...              0
# ...

# %%
from sklearn.preprocessing import StandardScaler
scalar=StandardScaler()
scalar.fit_transform(dff)
# Out:
# array([[ 0.13834079, -0.32548735, -0.23481945, ...,  0.32455977,
#         -0.25369274,  0.42551001],
#        [ 0.13834079, -0.32548735, -0.07529935, ...,  0.32455977,
#         -0.25369274,  0.67867164],
#        [ 0.13834079, -0.32548735,  0.77547454, ...,  0.32455977,
#         -0.25369274,  1.12592385],
#        ...,
#        [-0.84397981, -0.32548735,  0.45643433, ..., -2.45476897,
#          2.83121093,  1.75190816],
#        [ 3.08530259,  2.86638857, -1.83002049, ...,  0.32455977,
#         -0.25369274, -0.64620755],
#        [ 0.13834079, -0.32548735, -0.39433956, ...,  0.32455977,
#         -0.25369274, -0.13988429]])

# %%
X=dff.iloc[:,:-1]
Y=dff.iloc[:,-1]

# %% [markdown]
# # Correlation

# %%
corrr=X.corr()
fig=plt.figure(figsize=(25,15))
sns.heatmap(corrr)

# %%
columns = np.full((corrr.shape[0],), True)
for i in range(corrr.shape[0]):
    for j in range(i+1, corrr.shape[0]):
        if corrr.iloc[i,j] >= 0.7: #Generally correlatiob value <0.7 is considered a strong correaltion
            if columns[j]:
                columns[j] = False
                
columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True])

# %%
dff.drop(['BldgType','YearRemodAdd','Exterior2nd','Foundation','1stFlrSF','GrLivArea','BsmtFullBath','HalfBath','TotRmsAbvGrd','GarageYrBlt','GarageArea'],axis=1,inplace=True)
dff
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-41-fcce5327f8b4> in <module>
# ----> 1 dff.drop(['BldgType','YearRemodAdd','Exterior2nd','Foundation','1stFlrSF','GrLivArea','BsmtFullBath','HalfBath','TotRmsAbvGrd','GarageYrBlt','GarageArea'],axis=1,inplace=True)
#       2 dff
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
# ...

# %%
sns.heatmap(dff.isnull())

# %%
data_int=data.loc[:,data.dtypes==np.int64]
data_int.columns

# %%
#sm.qqplot(df['BsmtFinSF1'], loc = 4, scale = 3, line='s') #not normal
#sns.distplot(df['BsmtFinSF1'])
#skew(df['BsmtFinSF1'])
#df['BsmtFinSF1']=np.log(df['BsmtFinSF1'])
df['BsmtFinSF1']

# %%
import statsmodels.api as sm
from scipy.stats import skew,kurtosis
#sm.qqplot(df['MSSubClass'], loc = 4, scale = 3, line='s') #not normal
df['MSSubClass']=np.log(df['MSSubClass'])

#sm.qqplot(df['LotArea'], loc = 4, scale = 3, line='s') #not normal
df['LotArea']=np.log(df['LotArea'])

#sm.qqplot(df['OverallQual'], loc = 4, scale = 3, line='s')  #not normal
df['OverallQuale']=np.log(df['OverallQual'])

#sm.qqplot(df['OverallCond'], loc = 4, scale = 3, line='s')   #not normal
df['OverallCond']=np.log(df['OverallCond'])

#sm.qqplot(df['YearBuilt'], loc = 4, scale = 3, line='s') #not normal
#df['YearBuilt']=np.log(df['YearBuilt'])

#sm.qqplot(df['YearRemodAdd'], loc = 4, scale = 3, line='s') # not normal
#df['YearRemodAdd']=np.log(df['YearRemodAdd'])

sm.qqplot(df['BsmtFinSF1'], loc = 4, scale = 3, line='s') #not normal
#sns.distplot(df['BsmtFinSF1'])
#skew(df['BsmtFinSF1'])
#df['BsmtFinSF1']=np.log(df['BsmtFinSF1'])

#sm.qqplot(df['BsmtFinSF2'], loc = 4, scale = 3, line='s') #not Normal
#sns.distplot(df['BsmtFinSF2'])
#skew(df['BsmtFinSF2'])
#kurtosis(df['BsmtFinSF2'])
#df['BsmtFinSF2']=np.log(df['BsmtFinSF2'])

#sm.qqplot(df['BsmtUnfSF'], loc = 4, scale = 3, line='s') #Normal
#sns.distplot(df['BsmtUnfSF'])
#skew(df['BsmtUnfSF'])
#kurtosis(df['BsmtUnfSF'])


#sm.qqplot(df['TotalBsmtSF'], loc = 4, scale = 3, line='s') #not normal
#sns.distplot(df['TotalBsmtSF'])
#skew(df['TotalBsmtSF'])
#kurtosis(df['TotalBsmtSF'])
#df['TotalBsmtSF']=np.log(df['TotalBsmtSF'])

#sm.qqplot(df['1stFlrSF'], loc = 4, scale = 3, line='s') #not normal
#sns.distplot(df['1stFlrSF'])
#skew(df['1stFlrSF'])
#kurtosis(df['1stFlrSF'])
#df['1stFlrSF']=np.log(df['1stFlrSF'])

#sm.qqplot(df['LowQualFinSF'], loc = 4, scale = 3, line='s') #not normal
#sns.distplot(df['LowQualFinSF'])
#skew(df['LowQualFinSF'])
#kurtosis(df['LowQualFinSF'])
#df['LowQualFinSF']=np.log(df['LowQualFinSF'])

#sm.qqplot(df['GrLivArea'], loc = 4, scale = 3, line='s') #not normal
#sns.distplot(df['GrLivArea'])
#skew(df['GrLivArea'])
#kurtosis(df['GrLivArea'])
#df['GrLivArea']=np.log(df['GrLivArea'])

#sm.qqplot(df['BsmtHalfBath'], loc = 4, scale = 3, line='s') #not normal
#sns.distplot(df['BsmtHalfBath'])
#skew(df['BsmtHalfBath'])
#kurtosis(df['BsmtHalfBath'])
#df['BsmtHalfBath']=np.log(df['BsmtHalfBath'])

#sm.qqplot(df['FullBath'], loc = 4, scale = 3, line='s') # kurtosis and skewness -0.8
#sns.distplot(df['FullBath'])
#kew(df['FullBath'])
#kurtosis(df['FullBath'])
#df['FullBath']=np.log(df['FullBath'])

#sm.qqplot(df['HalfBath'], loc = 4, scale = 3, line='s') # kurtosis and skewness -1.7 and 0.6
#sns.distplot(df['HalfBath'])
#skew(df['HalfBath'])
#kurtosis(df['HalfBath'])
#df['HalfBath']=np.log(df['HalfBath'])

#sm.qqplot(df['BedroomAbvGr'], loc = 4, scale = 3, line='s') # not normal
#sns.distplot(df['BedroomAbvGr'])
#skew(df['BedroomAbvGr'])
#kurtosis(df['BedroomAbvGr'])
#df['BedroomAbvGr']=np.log(df['BedroomAbvGr'])

#sm.qqplot(df['KitchenAbvGr'], loc = 4, scale = 3, line='s') # not normal
#sns.distplot(df['KitchenAbvGrr'])
#skew(df['KitchenAbvGr'])
#kurtosis(df['KitchenAbvGr'])
#df['KitchenAbvGr']=np.log(df['KitchenAbvGr'])

#sm.qqplot(df['Fireplaces'], loc = 4, scale = 3, line='s') # normal
#sns.distplot(df['Fireplaces'])
#skew(df['Fireplaces'])
#kurtosis(df['Fireplaces'])


#sm.qqplot(df['GarageCars'], loc = 4, scale = 3, line='s') # normal
#sns.distplot(df['GarageCarss'])
#skew(df['GarageCars'])
#kurtosis(df['GarageCars'])


#sm.qqplot(df['GarageArea'], loc = 4, scale = 3, line='s') # normal
#sns.distplot(df['GarageCarss'])
#skew(df['GarageArea'])
#kurtosis(df['GarageArea'])

#sm.qqplot(df['WoodDeckSF'], loc = 4, scale = 3, line='s') # not normal
#sns.distplot(df['WoodDeckSF'])
#skew(df['WoodDeckSF'])
#kurtosis(df['WoodDeckSF'])
#df['WoodDeckSF']=np.log(df['WoodDeckSF'])

#sm.qqplot(df['OpenPorchSF'], loc = 4, scale = 3, line='s') # not normal
#sns.distplot(df['WoodDeckSF'])
#skew(df['OpenPorchSF'])
#kurtosis(df['OpenPorchSF'])
#df['OpenPorchSF']=np.log(df['OpenPorchSF'])

#sm.qqplot(df['EnclosedPorch'], loc = 4, scale = 3, line='s') # not normal
#sns.distplot(df['EnclosedPorch'])
#skew(df['EnclosedPorch'])
#kurtosis(df['EnclosedPorch'])
#df['EnclosedPorch']=np.log(df['EnclosedPorch'])

#sm.qqplot(df['3SsnPorch'], loc = 4, scale = 3, line='s') # not normal
#sns.distplot(df['3SsnPorch'])
#skew(df['3SsnPorch'])
#kurtosis(df['3SsnPorch'])
#df['3SsnPorch']=np.log(df['3SsnPorch'])

#sm.qqplot(df['ScreenPorch'], loc = 4, scale = 3, line='s') # not normal
#sns.distplot(df['ScreenPorch'])
#skew(df['ScreenPorch'])
#kurtosis(df['ScreenPorch'])
#df['ScreenPorch']=np.log(df['ScreenPorch'])

#sm.qqplot(df['PoolArea'], loc = 4, scale = 3, line='s') # not normal
#sns.distplot(df['PoolArea'])
#skew(df['PoolArea'])
#kurtosis(df['PoolArea'])
#df['PoolArea']=np.log(df['PoolArea'])

#sm.qqplot(df['MiscVal'], loc = 4, scale = 3, line='s') # not normal
#sns.distplot(df['MiscVal'])
#skew(df['MiscVal'])
#kurtosis(df['MiscVal'])
#df['MiscVal']=np.log(df['MiscVal'])  #works

#sm.qqplot(df['MoSold'], loc = 4, scale = 3, line='s') # normal
#sns.distplot(df['MoSold'])
#skew(df['MoSold'])
#kurtosis(df['MoSold'])

#sm.qqplot(df['YrSold'], loc = 4, scale = 3, line='s') # normal
#sns.distplot(df['YrSold'])
#skew(df['YrSold'])
#kurtosis(df['YrSold'])

#sm.qqplot(df['SalePrice'], loc = 4, scale = 3, line='s') #not normal
#sns.distplot(df['SalePrice'])
#skew(df['SalePrice'])
#kurtosis(df['SalePrice'])
#df['SalePrice']=np.log(df['SalePrice']) #works

# %%
dff.shape

# %%
#Splitting data as X and Y part
x=dff.iloc[:,:-1]
y=dff.iloc[:,-1]

# %%
#Splitting data as test and train part
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=10)
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((486, 63), (122, 63), (486,), (122,))

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
y_predict=model.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
mean_squared_error(y_test,y_predict)
# Out:
# 482472363.23479587

# %%
np.sqrt(mean_squared_error(y_test,y_predict))
# Out:
# 21965.25354360372

# %%
mean_absolute_error(y_test,y_predict)
# Out:
# 15439.480247713827

# %%
r2_score(y_test,y_predict)
# Out:
# 0.8295591692304143

# %%
model.score(x_train,y_train)
# Out:
# 0.9128873449670842

# %%
model.score(x_test,y_test)
# Out:
# 0.8295591692304143

# %%
from sklearn.model_selection import cross_val_score
scores=cross_val_score(model,X,Y,scoring='r2',cv=10)
scores
# Out:
# array([0.91842714, 0.90905904, 0.91983443, 0.92547034, 0.79259541,
#        0.90713872, 0.92868764, 0.94312142, 0.91598888, 0.80668106])

# %%
import sklearn
sklearn.metrics.SCORERS.keys()    #to get all the evaluation metrices

# %%
print(score)
print("average score: ",score.mean())
print("Std dev: ",score.std()) #std of <0.05 is good, is nothing but the significance level

# %% [markdown]
# k-fold cross validation

# %%
from sklearn.model_selection import cross_val_score
score=cross_val_score(model,x_test,y_test,scoring='r2',cv=10)
score

# %%
nmse=cross_val_score(model,X,Y,scoring='r2',cv=5)
np.mean(nmse)

# %%
score

# %%
corrmat=df.corr()

# %%
pd.set_option('display.max_columns', None) #to display all the columns in a dataset
pd.set_option('display.max_rows', None) #To display all the rows in a dataset
corrmat

# %% [markdown]
# # Feature selection

# %%
corrr=X.corr()
fig=plt.figure(figsize=(25,15))
sns.heatmap(corrr)

# %%
df.columns

# %%
df.columns[61]

# %%
columns

# %%
#To avoid the overfitting we are selecting best subsets from dataset, so we have computed correlation matrix and 
#removed the columns which have strong correlation.
#colums having highest correlations are: HouseStyle, MasVnrType, 2ndFlrSF, BsmtFullBath, Functional, GarageFinish, GarageQual

# %%
df.drop(['HouseStyle', 'MasVnrType', '2ndFlrSF', 'BsmtFullBath', 'Functional', 'GarageFinish', 'GarageQual'],axis=1,inplace=True)
df

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
#Splitting data as test and train part
from sklearn.model_selection import train_test_split
xx_train,xx_test,yy_train,yy_test=train_test_split(x,y,test_size=0.2,random_state=20)
xx_train.shape,xx_test.shape,yy_train.shape,yy_test.shape

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(xx_train,yy_train)
yy_predict=model.predict(xx_test)

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
r2_score(yy_test,yy_predict)

# %%
import statsmodels.api as sm
ml=sm.OLS(Y,X) 
results=ml.fit()
pr=results.predict(xx_test)

# %%
results.rsquared

# %%
results.rsquared_adj

# %%
from sklearn.linear_model import Ridge
R=Ridge()
R.fit(x_train,y_train)
y_pr=R.predict(x_test)
y_pr
r2_score(y_test,y_pr)

# %%
df.iloc[:,5:10].boxplot()

# %%
from numpy import random
nr=random.normal(size=100)
sns.distplot(nr)
sns.distplot(df[''])

# %%
p=pd.DataFrame(nr)
p.boxplot()

# %%
import random
random.randn(0,1)
